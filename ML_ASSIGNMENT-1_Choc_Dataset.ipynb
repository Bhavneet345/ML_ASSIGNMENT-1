# %%
# importing all the neccessary dependencies for calculations and evaluation of 6 specified models
# importing all the learning classifiers following six (6) algorithms:
# 1. a single decision tree (DT)
# 2. a random forest (RF) learner
# 3. a support vector machine (SVM)
# 4. a grae
# 5. a multi-layer perceptron (MLP)
# 6. a k‐nearest neighbour (k-NN) classifier
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
# confusion metric and accuracy score evaluation
from sklearn.metrics import confusion_matrix,accuracy_score
# Precision and recall
from sklearn.metrics import classification_report
# ROC curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# ## Functions for training all 6 models on both the datasets which take X_train and Y_train for both datasets individually

# %% [markdown]
# #### Function to train a single Decision Tree (DT)

# %%
# criterion parameter has value entropy which is measurement of impurities in the information processed in machine learning
def decisionTree(X_train, y_train):
    classifier = DecisionTreeClassifier(criterion="entropy")
    classifier.fit(X_train,y_train)
    return classifier

# %% [markdown]
# #### Function to train a Random Forest classifier

# %%
# n_estimators specify the number of decision trees in the random forest classifier 
def randomForest(X_train, y_train):
    clf = RandomForestClassifier(n_estimators=100,criterion="entropy",random_state=0)
    clf.fit(X_train,y_train)
    return clf

# %% [markdown]
# #### Function to train a Support Vector Machine

# %%
# used linear kernel in Support vector machine
def SVM(X_train, y_train):
    classifier = SVC(kernel="linear",random_state=0)
    classifier.fit(X_train,y_train)
    return classifier

# %% [markdown]
# #### Function to train a Gradient Boosting classifier

# %%
def gradientBoosting(X_train, y_train):
    classifier = GradientBoostingClassifier()
    classifier.fit(X_train,y_train)
    return classifier

# %% [markdown]
# #### Function to train a Multi layer perceptron

# %%
def mlpClassifier(X_train, y_train):
    classifier = MLPClassifier(max_iter=1500)
    classifier.fit(X_train,y_train)
    return classifier

# %% [markdown]
# #### Function to train a K-NN classifier

# %%
# n_neighbors specify the number of nearest neighbors and p specifies the Euclidean distance
def KNN(X_train, y_train):
    classifier = KNeighborsClassifier(n_neighbors=5,p=2,metric="minkowski")
    classifier.fit(X_train,y_train)
    return classifier

# %% [markdown]
# #### Funciton to compute the confusion matrix

# %%
# y_test represents the actual target variables 
# y_pred specifies the predicted target values
def matrixCalc(y_test, y_pred):
    metric = confusion_matrix(y_test,y_pred)
    print(metric)

# %% [markdown]
# #### Function to calculate precision and recall classification report

# %%
def classificationReport(y_test, y_pred):
    print(classification_report(y_test, y_pred))

# %% [markdown]
# # Dataset with label choc(chocolate)

# %% [markdown]
# #### Importing the dataset with target label = "choc" and droping the "unnamed: 0" columns and specifying the number of rows and columns

# %%
df_choc = pd.read_csv("/Users/bhavneetsingh/Desktop/ML Assignment/ML_assignment-1_choc.csv")
df_choc.drop(["Unnamed: 0"], inplace = True, axis = 1)
df_choc.shape
# Out:
# (1885, 13)

# %%
df_choc.head()
# Out:
#        age   gender  education  country  ethnicity   nscore   escore   oscore  \
# 0  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545 -0.58331
# 1 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886  1.43533
# 2  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523 -0.84732
# 3 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615 -0.01928
# 4  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340 -0.45174
#
#     ascore   cscore  impuslive       ss  choc
# 0 -0.91699 -0.00665   -0.21712 -1.18084  user
# 1  0.76096 -0.14277   -0.71126 -0.21575  user
# 2 -1.62090 -1.01450   -1.37983  0.40148  user
# 3  0.59042  0.58489   -1.37983 -1.18084  user
# 4 -0.30172  1.30612   -0.21712 -0.21575  user

# %% [markdown]
# #### Seperating the features and the target variables

# %%
X_choc = df_choc.iloc[:,:-1].values
y_choc = df_choc.iloc[:,-1:].values

# %% [markdown]
# #### Splitting the dataset into test set and training set

# %%
X_train_choc,X_test_choc,y_train_choc,y_test_choc = train_test_split(X_choc,y_choc,test_size=0.2,random_state=0)

# %% [markdown]
# ## Decision tree classifier

# %%
# training the model on chocolate data
tree =  decisionTree(X_train_choc, y_train_choc)

# %%
# predicting the test results 
y_pred_choc_decision_tree = tree.predict(X_test_choc)
np.concatenate((y_test_choc.reshape(y_test_choc.size,1),y_pred_choc_decision_tree.reshape(y_test_choc.size,1)),axis=1)
# Out:
# array([['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['non-user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
# ...

# %%
# Accuracy score and confusion matrix 
matrixCalc(y_test_choc,y_pred_choc_decison_tree)
# Out:
# [[  0   6]
#  [ 12 359]]

# %%
accuracy = accuracy_score(y_test_choc,y_pred_choc_decison_tree)
print(f"Accuracy is: {round(accuracy*100, 2)}%")
# Out:
# Accuracy is: 95.23%

# %%
# precision and recall
classificationReport(y_test_choc,y_pred_choc_decison_tree)
# Out:
#               precision    recall  f1-score   support
#
#     non-user       0.00      0.00      0.00         6
#         user       0.98      0.97      0.98       371
#
#     accuracy                           0.95       377
#    macro avg       0.49      0.48      0.49       377
# weighted avg       0.97      0.95      0.96       377

# %% [markdown]
# ## Random Forest classifier

# %%
# training the model on chocolate data
forest =  randomForest(X_train_choc, y_train_choc.ravel())

# %%
# predicting the test results 
y_pred_choc_forest = forest.predict(X_test_choc)
np.concatenate((y_test_choc.reshape(y_test_choc.size,1),y_pred_choc_forest.reshape(y_test_choc.size,1)),axis=1)
# Out:
# array([['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['non-user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
# ...

# %%
# Accuracy score and confusion matrix 
matrixCalc(y_test_choc,y_pred_choc_forest)
# Out:
# [[  0   6]
#  [  0 371]]

# %%
accuracy = accuracy_score(y_test_choc,y_pred_choc_forest)
print(f"Accuracy is: {round(accuracy*100, 2)}%")
# Out:
# Accuracy is: 98.41%

# %%
# precision and recall
classificationReport(y_test_choc,y_pred_choc_forest)
# Out:
#               precision    recall  f1-score   support
#
#     non-user       0.00      0.00      0.00         6
#         user       0.98      1.00      0.99       371
#
#     accuracy                           0.98       377
#    macro avg       0.49      0.50      0.50       377
# weighted avg       0.97      0.98      0.98       377
# /Users/bhavneetsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/bhavneetsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## Support Vector Machine

# %%
# training the model on chocolate data
svm =  SVM(X_train_choc, y_train_choc.ravel())

# %%
# predicting the test results 
y_pred_choc_svm = svm.predict(X_test_choc)
np.concatenate((y_test_choc.reshape(y_test_choc.size,1),y_pred_choc_svm.reshape(y_test_choc.size,1)),axis=1)
# Out:
# array([['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['non-user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
# ...

# %%
# Accuracy score and confusion matrix 
matrixCalc(y_test_choc,y_pred_choc_svm)
# Out:
# [[  0   6]
#  [  0 371]]

# %%
accuracy = accuracy_score(y_test_choc,y_pred_choc_svm)
print(f"Accuracy is: {round(accuracy*100, 2)}%")
# Out:
# Accuracy is: 98.41%

# %%
# precision and recall
classificationReport(y_test_choc,y_pred_choc_svm)
# Out:
#               precision    recall  f1-score   support
#
#     non-user       0.00      0.00      0.00         6
#         user       0.98      1.00      0.99       371
#
#     accuracy                           0.98       377
#    macro avg       0.49      0.50      0.50       377
# weighted avg       0.97      0.98      0.98       377
# /Users/bhavneetsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/bhavneetsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## Gradient Boosting ensemble

# %%
# training the model on chocolate data
boost =  gradientBoosting(X_train_choc, y_train_choc.ravel())

# %%
# predicting the test results 
y_pred_choc_boost = boost.predict(X_test_choc)
np.concatenate((y_test_choc.reshape(y_test_choc.size,1),y_pred_choc_boost.reshape(y_test_choc.size,1)),axis=1)
# Out:
# array([['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['non-user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'non-user'],
#        ['user', 'user'],
#        ['user', 'user'],
# ...

# %%
# Accuracy score and confusion matrix 
matrixCalc(y_test_choc,y_pred_choc_boost)
# Out:
# [[  0   6]
#  [  1 370]]

# %%
accuracy = accuracy_score(y_test_choc,y_pred_choc_boost)
print(f"Accuracy is: {round(accuracy*100, 2)}%")
# Out:
# Accuracy is: 98.14%

# %%
# precision and recall
classificationReport(y_test_choc,y_pred_choc_boost)
# Out:
#               precision    recall  f1-score   support
#
#     non-user       0.00      0.00      0.00         6
#         user       0.98      1.00      0.99       371
#
#     accuracy                           0.98       377
#    macro avg       0.49      0.50      0.50       377
# weighted avg       0.97      0.98      0.97       377

# %% [markdown]
# ## Multilayer Perceptron

# %%
# training the model on chocolate data
mlp =  mlpClassifier(X_train_choc, y_train_choc.ravel())

# %%
# predicting the test results 
y_pred_choc_mlp = mlp.predict(X_test_choc)
np.concatenate((y_test_choc.reshape(y_test_choc.size,1),y_pred_choc_mlp.reshape(y_test_choc.size,1)),axis=1)
# Out:
# array([['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['non-user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
# ...

# %%
# Accuracy score and confusion matrix 
matrixCalc(y_test_choc,y_pred_choc_mlp)
# Out:
# [[  0   6]
#  [  2 369]]

# %%
accuracy = accuracy_score(y_test_choc,y_pred_choc_mlp)
print(f"Accuracy is: {round(accuracy*100, 2)}%")
# Out:
# Accuracy is: 97.88%

# %%
# precision and recall
classificationReport(y_test_choc,y_pred_choc_mlp)
# Out:
#               precision    recall  f1-score   support
#
#     non-user       0.00      0.00      0.00         6
#         user       0.98      0.99      0.99       371
#
#     accuracy                           0.98       377
#    macro avg       0.49      0.50      0.49       377
# weighted avg       0.97      0.98      0.97       377

# %% [markdown]
# ## KNN

# %%
# training the model on chocolate data
knn =  KNN(X_train_choc, y_train_choc.ravel())

# %%
# predicting the test results 
y_pred_choc_knn = knn.predict(X_test_choc)
np.concatenate((y_test_choc.reshape(y_test_choc.size,1),y_pred_choc_knn.reshape(y_test_choc.size,1)),axis=1)
# Out:
# array([['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['non-user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
#        ['user', 'user'],
# ...

# %%
# Accuracy score and confusion matrix 
matrixCalc(y_test_choc,y_pred_choc_knn)
# Out:
# [[  0   6]
#  [  0 371]]

# %%
accuracy = accuracy_score(y_test_choc,y_pred_choc_knn)
print(f"Accuracy is: {round(accuracy*100, 2)}%")
# Out:
# Accuracy is: 98.41%

# %%
# precision and recall
classificationReport(y_test_choc,y_pred_choc_knn)
# Out:
#               precision    recall  f1-score   support
#
#     non-user       0.00      0.00      0.00         6
#         user       0.98      1.00      0.99       371
#
#     accuracy                           0.98       377
#    macro avg       0.49      0.50      0.50       377
# weighted avg       0.97      0.98      0.98       377
# /Users/bhavneetsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/bhavneetsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## ROC EVALUATION

# %%
y_true = y_test_choc
y_true[y_true == "user"] = 1
y_true[y_true == "non-user"] = 0
y_true = y_true.astype(int)

y_pred_choc_decison_tree[y_pred_choc_decison_tree == "user"] = 1
y_pred_choc_decison_tree[y_pred_choc_decison_tree == "non-user"] = 0
y_pred_choc_decison_tree = y_pred_choc_decison_tree.astype(int)

y_pred_choc_forest[y_pred_choc_forest == "user"] = 1
y_pred_choc_forest[y_pred_choc_forest == "non-user"] = 0
y_pred_choc_forest = y_pred_choc_forest.astype(int)

y_pred_choc_svm[y_pred_choc_svm == "user"] = 1
y_pred_choc_svm[y_pred_choc_svm == "non-user"] = 0
y_pred_choc_svm = y_pred_choc_svm.astype(int)

y_pred_choc_boost[y_pred_choc_boost == "user"] = 1
y_pred_choc_boost[y_pred_choc_boost == "non-user"] = 0
y_pred_choc_boost = y_pred_choc_boost.astype(int)

y_pred_choc_mlp[y_pred_choc_mlp == "user"] = 1
y_pred_choc_mlp[y_pred_choc_mlp == "non-user"] = 0
y_pred_choc_mlp = y_pred_choc_mlp.astype(int)

y_pred_choc_knn[y_pred_choc_knn == "user"] = 1
y_pred_choc_knn[y_pred_choc_knn == "non-user"] = 0
y_pred_choc_knn = y_pred_choc_knn.astype(int)

y_preds = [
    y_pred_choc_decison_tree,  # Predictions from model 1
    y_pred_choc_forest,  # Predictions from model 2
    y_pred_choc_svm,  # Predictions from model 3
    y_pred_choc_boost,  # Predictions from model 4
    y_pred_choc_mlp,  # Predictions from model 5
    y_pred_choc_knn,  # Predictions from model 6
]
model_names = ['Decision Tree', 'Random Forest', 'Support Vector Machine', 'Gradient Boost', 'MLP', 'KNN']
plt.figure(figsize=(10, 8))

for i, y_pred in enumerate(y_preds):
    fpr, tpr, _ = roc_curve(y_true, y_pred, pos_label = 1)
    roc_auc = auc(fpr, tpr)
    
    plt.plot(fpr, tpr, lw=2, label=f'{model_names[i]} (AUC = {roc_auc:.2f})')

# Plot diagonal line
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiple Models')
plt.legend(loc="lower right")
plt.show()
# Out:
# /var/folders/bs/nn1_9vm534jds0wld0rskgf40000gn/T/ipykernel_8102/517831206.py:6: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   y_pred_choc_decison_tree[y_pred_choc_decison_tree == "user"] = 1
# /var/folders/bs/nn1_9vm534jds0wld0rskgf40000gn/T/ipykernel_8102/517831206.py:7: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   y_pred_choc_decison_tree[y_pred_choc_decison_tree == "non-user"] = 0
# /var/folders/bs/nn1_9vm534jds0wld0rskgf40000gn/T/ipykernel_8102/517831206.py:10: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   y_pred_choc_forest[y_pred_choc_forest == "user"] = 1
# ...
